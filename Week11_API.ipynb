# %%
import requests
import pandas as pd

api_key = 'Vk4bzBGu7HM1tENQCZNGIY6QcKseU6A9' 
query = 'space exploration'  
url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={query}&api-key={api_key}'

response = requests.get(url)
data = response.json()

articles = data['response']['docs']
df = pd.DataFrame(articles)

# %%
df.head()
# Out:
#                                             abstract  \
# 0  It’s time to talk about the extraterrestrial b...
# 1  A SpaceX Falcon Heavy rocket launched the prob...
# 2  The probe launched on a SpaceX Falcon Heavy ro...
# 3  The conference on Nov. 29 will bring together ...
# 4  The prediction is the latest in a series of am...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2023/11/05/opinion/spa...
# 1  https://www.nytimes.com/video/science/space/10...
# 2  https://www.nytimes.com/2023/10/13/science/nas...
# 3  https://www.nytimes.com/2023/10/12/business/de...
# 4  https://www.nytimes.com/2023/10/05/science/elo...
#
#                                              snippet  \
# 0  It’s time to talk about the extraterrestrial b...
# 1  A SpaceX Falcon Heavy rocket launched the prob...
# 2  The probe launched on a SpaceX Falcon Heavy ro...
# 3  The conference on Nov. 29 will bring together ...
# ...
